# %% [markdown]
# # HANDLING MISSING VALUES

# %% [markdown]
# 1. Removal method
# 2. imputation method
#   * **univariant**  [neumerical-solution]
#     * mean/median/mode
#     * Arbitrory values
#     * End of distribution  <br>
#
#   *  **Multivariant**  [important] <br>
#       * k-NEARSET NEGHIBOUR  <br>
#       * iterative method using loops and nested loops using with different values of i j k  or recurvise fucn

# %%
# data = {
#     "NAME":["ALI","AHMED","AWAIS",3,"SAIM","Asad","KAMRAN"],
#     "AGE":[23,24,25,26,27,3,29],
#     "Salary":[1000,2000,3000,3,5000,6000,3],
# }


import pandas as pd

# dataframe = pd.DataFrame(data)

# dataframe.to_csv("Handling_missing.csv", index=False)


# Reading the CSV file

dataframe = pd.read_csv("Handling_missing.csv")
print(dataframe)


# HANDLING MISSING VALUES USING UNIVARIANT METHODS 
# 1. Drop the rows with missing values
# dataframe = dataframe.dropna()
# 2. Drop the columns with missing values
# dataframe = dataframe.dropna(axis=1)
# 3. Fill the missing values with a specific value  arbritrary value
# dataframe = dataframe.fillna(0)
# 4. Fill the missing values with the mean of the column
# dataframe = dataframe.fillna(dataframe.mean())
# 5. Fill the missing values with the median of the column
# dataframe = dataframe.fillna(dataframe.median())
# 6. Fill the missing values with the mode of the column
# dataframe = dataframe.fillna(dataframe.mode().iloc[0])
# 7. Fill the missing values with the previous value
# dataframe = dataframe.fillna(method='ffill',inplace=True)
# 8. Fill the missing values with the next value
# dataframe = dataframe.fillna(method='bfill')
# Out:
#      NAME   AGE  Salary
# 0     ALI  23.0  1000.0
# 1   AHMED  24.0  2000.0
# 2   AWAIS  25.0  3000.0
# 3     NaN  26.0     NaN
# 4    SAIM  27.0  5000.0
# 5    Asad   NaN  6000.0
# 6  KAMRAN  29.0     NaN
# C:\Users\mujta\AppData\Local\Temp\ipykernel_8776\2657783397.py:35: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataframe = dataframe.fillna(method='ffill',inplace=True)
