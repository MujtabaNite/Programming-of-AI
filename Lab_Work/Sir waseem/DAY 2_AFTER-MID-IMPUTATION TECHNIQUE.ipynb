# %% [markdown]
# # HANDLING MISSING VALUES

# %%
import pandas as pd

dataframe = pd.read_csv("data.csv")
print(dataframe)
# Out:
#                                 CONS_NO  FLAG  2014/1/1  2014/1/10  2014/1/11  \
# 0      0387DD8A07E07FDA6271170F86AD9151     1       NaN        NaN        NaN
# 1      01D6177B5D4FFE0CABA9EF17DAFC2B84     1       NaN        NaN        NaN
# 2      4B75AC4F2D8434CFF62DB64D0BB43103     1       NaN        NaN        NaN
# 3      B32AC8CC6D5D805AC053557AB05F5343     1       NaN        NaN        NaN
# 4      EDFC78B07BA2908B3395C4EB2304665E     1      2.90       3.42       3.81
# ...                                 ...   ...       ...        ...        ...
# 42367  F1472871E1AFF49D4289564B6377D76C     0       NaN        NaN        NaN
# 42368  F3C8BBCD2DC26C1E0249DEEF6A4256B7     0      2.70       4.39       3.95
# 42369  A9A0FE83467A680FBFB0DBFC910DF227     0      0.58       0.84       1.61
# 42370  D9A6ADA018FA46A55D5438370456AA45     0     16.89      13.84      13.50
# 42371  F3406636BAD1E6E0826E8EDDC9A1BF00     0       NaN        NaN        NaN
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

for column in dataframe.columns:
    if dataframe[column].dtype == 'object': 
        dataframe[column] = label_encoder.fit_transform(dataframe[column])

# %%
dataframe
# Out:
#        CONS_NO  FLAG  2014/1/1  2014/1/10  2014/1/11  2014/1/12  2014/1/13  \
# 0          584     1       NaN        NaN        NaN        NaN        NaN
# 1          320     1       NaN        NaN        NaN        NaN        NaN
# 2        12448     1       NaN        NaN        NaN        NaN        NaN
# 3        29736     1       NaN        NaN        NaN        NaN        NaN
# 4        39452     1      2.90       3.42       3.81       4.58       3.56
# ...        ...   ...       ...        ...        ...        ...        ...
# 42367    39985     0       NaN        NaN        NaN        NaN        NaN
# 42368    40428     0      2.70       4.39       3.95       0.00       0.00
# 42369    28190     0      0.58       0.84       1.61       0.90       0.60
# 42370    36129     0     16.89      13.84      13.50      14.60      14.46
# 42371    40345     0       NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# ploting heatmap for mising values
plt.figure(figsize=(10, 6))
sns.heatmap(dataframe.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
# using the mean to fill missing values
dataframe.fillna(dataframe.mean(), inplace=True)

# using the mode to fill missing values
# dataframe.fillna(dataframe.mode()[0], inplace=True)

# using the median to fill missing values
# dataframe.fillna(dataframe.median(), inplace=True)


# using the forward fill method to fill missing values
# dataframe.fillna(method='ffill', inplace=True)
# using the backward fill method to fill missing values
# dataframe.fillna(method='bfill', inplace=True)


# using the minimum to fill missing values
# dataframe.fillna(dataframe.min(), inplace=True)
# using the maximum to fill missing values
# dataframe.fillna(dataframe.max(), inplace=True)

# using the interpolation method to fill missing values
# dataframe.interpolate(method='linear', inplace=True)

# using the dropna method to drop missing values
# dataframe.dropna(inplace=True)


# using arbitrary value to fill missing values
# dataframe.fillna(44, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# ploting heatmap for mising values
plt.figure(figsize=(10, 6))
sns.heatmap(dataframe.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()
